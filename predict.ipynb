# %%
import pandas as pd

# %%
df = pd.read_csv("nba_games.csv", index_col=0)

# %%
df
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  ...
# 1      240.0  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  ...
# 2      240.0  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  ...
# 3      240.0  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  ...
# 4      240.0  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 23035  240.0  240.0  38.0  86.0  0.442   9.0  25.0  0.360  14.0  16.0  ...
# 23036  240.0  240.0  29.0  80.0  0.363  14.0  41.0  0.341  12.0  13.0  ...
# 23037  240.0  240.0  46.0  91.0  0.505  15.0  37.0  0.405  15.0  22.0  ...
# 23038  240.0  240.0  35.0  78.0  0.449  11.0  37.0  0.297   7.0  13.0  ...
# 23039  240.0  240.0  38.0  89.0  0.427  13.0  39.0  0.333  17.0  20.0  ...
#
# ...

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
def add_target(group):
    group["target"] = group["won"].shift(-1)
    return group

df = df.groupby("team", group_keys=False).apply(add_target)
# Out:
# C:\Users\yb200\AppData\Local\Temp\ipykernel_17208\3431415784.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# C:\Users\yb200\AppData\Local\Temp\ipykernel_17208\3431415784.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# ...

# %%
df[df["team"] == "WAS"]
# Out:
#           mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 8      240.0  33.0   84.0  0.393   7.0  28.0  0.250  15.0  25.0  0.600  ...
# 51     240.0  35.0   68.0  0.515  12.0  21.0  0.571  36.0  44.0  0.818  ...
# 65     240.0  38.0   90.0  0.422   6.0  22.0  0.273  28.0  33.0  0.848  ...
# 118    240.0  42.0   87.0  0.483   8.0  23.0  0.348  10.0  14.0  0.714  ...
# 166    240.0  36.0   88.0  0.409   8.0  25.0  0.320  18.0  23.0  0.783  ...
# ...      ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 22700  240.0  38.0   88.0  0.432   5.0  33.0  0.152  21.0  30.0  0.700  ...
# 22726  240.0  42.0   89.0  0.472  16.0  40.0  0.400  22.0  30.0  0.733  ...
# 22763  240.0  44.0   89.0  0.494  20.0  43.0  0.465  13.0  17.0  0.765  ...
# 22813  240.0  45.0   86.0  0.523  18.0  43.0  0.419  19.0  29.0  0.655  ...
# 22851  240.0  49.0  103.0  0.476  14.0  38.0  0.368  10.0  10.0  1.000  ...
#
# ...

# %%
df["target"][pd.isnull(df["target"])] = 2
df["target"] = df["target"].astype(int, errors="ignore")
# Out:
# C:\Users\yb200\AppData\Local\Temp\ipykernel_17208\2400510588.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["target"][pd.isnull(df["target"])] = 2
# ...

# %%
df["won"].value_counts()
# Out:
# won
# True     11520
# False    11520
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    11506
# 0    11504
# 2       30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df).sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'orb',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=138)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta   orb  ...  \
# 0      240.0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  23.0  ...
# 1      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0   7.0  ...
# 2      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  11.0  ...
# 3      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0   7.0  ...
# 4      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0   8.0  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...   ...  ...
# 23035  240.0  38.0  86.0  0.442   9.0  25.0  0.360  14.0  16.0   7.0  ...
# 23036  240.0  29.0  80.0  0.363  14.0  41.0  0.341  12.0  13.0   4.0  ...
# 23037  240.0  46.0  91.0  0.505  15.0  37.0  0.405  15.0  22.0  13.0  ...
# 23038  240.0  35.0  78.0  0.449  11.0  37.0  0.297   7.0  13.0   7.0  ...
# 23039  240.0  38.0  89.0  0.427  13.0  39.0  0.333  17.0  20.0  15.0  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

lr = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs', max_iter=3000)

split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(lr, 
                                n_features_to_select=30, 
                                direction="forward",
                                cv=split,
                                n_jobs=1
                               )

# %%
removed_columns = ["season", "date", "won", "target", "team", "team_opp"]
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.391304  0.529412  0.277512  0.413793  0.378788  0.491686
# 1      0.0  0.391304  0.323529  0.435407  0.275862  0.348485  0.351544
# 2      0.0  0.413043  0.500000  0.322967  0.310345  0.378788  0.368171
# 3      0.0  0.391304  0.397059  0.373206  0.241379  0.227273  0.437055
# 4      0.0  0.347826  0.338235  0.366029  0.206897  0.212121  0.395487
# ...    ...       ...       ...       ...       ...       ...       ...
# 23035  0.0  0.413043  0.382353  0.413876  0.310345  0.318182  0.427553
# 23036  0.0  0.217391  0.294118  0.224880  0.482759  0.560606  0.404988
# 23037  0.0  0.586957  0.455882  0.564593  0.517241  0.500000  0.480998
# 23038  0.0  0.347826  0.264706  0.430622  0.379310  0.500000  0.352732
# 23039  0.0  0.413043  0.426471  0.377990  0.448276  0.530303  0.395487
#
#              ft       fta       orb  ...  usg%_max_opp  ortg_max_opp  \
# ...

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=LogisticRegression(max_iter=3000),
#                           n_features_to_select=30, n_jobs=1)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['3p%',
#  'tov',
#  'pts',
#  'ts%',
#  'efg%',
#  'drb%',
#  'trb%',
#  'tov%',
#  'usg%',
#  'fga_max',
#  'ft_max',
#  'fta_max',
#  'gmsc_max',
#  'trb%_max',
#  'stl%_max',
#  'tov%_max',
#  'total',
#  'home',
#  'fg_opp',
#  'pts_opp',
#  'orb%_opp',
#  'usg%_opp',
#  '3p_max_opp',
#  'tov_max_opp',
#  'orb%_max_opp',
#  'trb%_max_opp',
#  'stl%_max_opp',
#  'usg%_max_opp',
#  'total_opp',
#  'home_opp']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    
    seasons = sorted(data["season"].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        train = data[data["season"] < season]
        test = data[data["season"] == season]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, lr, predictors)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5449690837549185

# %%
df.groupby(["home"]).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# C:\Users\yb200\AppData\Local\Temp\ipykernel_17208\183910857.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby(["home"]).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# home
# 0.0    0.429948
# 1.0    0.570052
# dtype: float64

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.391304  0.529412  0.277512  0.413793  0.378788  0.491686
# 1      0.0  0.391304  0.323529  0.435407  0.275862  0.348485  0.351544
# 2      0.0  0.413043  0.500000  0.322967  0.310345  0.378788  0.368171
# 3      0.0  0.391304  0.397059  0.373206  0.241379  0.227273  0.437055
# 4      0.0  0.347826  0.338235  0.366029  0.206897  0.212121  0.395487
# ...    ...       ...       ...       ...       ...       ...       ...
# 23035  0.0  0.413043  0.382353  0.413876  0.310345  0.318182  0.427553
# 23036  0.0  0.217391  0.294118  0.224880  0.482759  0.560606  0.404988
# 23037  0.0  0.586957  0.455882  0.564593  0.517241  0.500000  0.480998
# 23038  0.0  0.347826  0.264706  0.430622  0.379310  0.500000  0.352732
# 23039  0.0  0.413043  0.426471  0.377990  0.448276  0.530303  0.395487
#
#              ft       fta       orb  ...  usg%_max_opp  ortg_max_opp  \
# ...

# %%
df_rolling = df[list(selected_columns) + ["won", "team", "season"]]
numeric_columns = df_rolling.select_dtypes(include='number').columns

def find_team_averages(team):
    rolling = team[numeric_columns].rolling(10).mean()
    rolling = rolling.drop(columns=['season'], errors='ignore')
    return team[['team', 'season']].join(rolling)

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)
# Out:
# C:\Users\yb200\AppData\Local\Temp\ipykernel_17208\589824417.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#       team  season     mp        fg       fga       fg%        3p       3pa  \
# 0      DET    2016    NaN       NaN       NaN       NaN       NaN       NaN
# 1      ATL    2016    NaN       NaN       NaN       NaN       NaN       NaN
# 2      CLE    2016    NaN       NaN       NaN       NaN       NaN       NaN
# 3      CHI    2016    NaN       NaN       NaN       NaN       NaN       NaN
# 4      NOP    2016    NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...     ...    ...       ...       ...       ...       ...       ...
# 23035  DAL    2024  0.000  0.445652  0.311765  0.524163  0.389655  0.401515
# 23036  BOS    2024  0.025  0.450000  0.360294  0.479426  0.510345  0.568182
# 23037  DAL    2024  0.000  0.458696  0.333824  0.519139  0.393103  0.404545
# 23038  DAL    2024  0.000  0.443478  0.327941  0.504067  0.375862  0.409091
# 23039  BOS    2024  0.025  0.450000  0.376471  0.465072  0.513793  0.578788
#
# ...

# %%
# Assuming df_rolling originally had columns ['mp', 'fg', etc.], manually restore them:
original_columns = [col.replace('_10', '') for col in df_rolling.columns]  # Remove the extra '_10' suffixes
df_rolling.columns = original_columns

rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols

# %%
df_rolling
# Out:
#       team_10  season_10  mp_10     fg_10    fga_10    fg%_10     3p_10  \
# 0         DET       2016    NaN       NaN       NaN       NaN       NaN
# 1         ATL       2016    NaN       NaN       NaN       NaN       NaN
# 2         CLE       2016    NaN       NaN       NaN       NaN       NaN
# 3         CHI       2016    NaN       NaN       NaN       NaN       NaN
# 4         NOP       2016    NaN       NaN       NaN       NaN       NaN
# ...       ...        ...    ...       ...       ...       ...       ...
# 23035     DAL       2024  0.000  0.445652  0.311765  0.524163  0.389655
# 23036     BOS       2024  0.025  0.450000  0.360294  0.479426  0.510345
# 23037     DAL       2024  0.000  0.458696  0.333824  0.519139  0.393103
# 23038     DAL       2024  0.000  0.443478  0.327941  0.504067  0.375862
# 23039     BOS       2024  0.025  0.450000  0.376471  0.465072  0.513793
#
#          3pa_10    3p%_10     ft_10  ...  trb%_max_opp_10  ast%_max_opp_10  \
# ...

# %%
df = pd.concat([df, df_rolling], axis=1)

# %%
df = df.dropna()

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.500000  0.382353  0.523923  0.344828  0.333333  0.457245
# 249    0.0  0.630435  0.426471  0.645933  0.620690  0.515152  0.562945
# 254    0.0  0.456522  0.500000  0.375598  0.379310  0.348485  0.483373
# 255    0.0  0.326087  0.250000  0.413876  0.310345  0.257576  0.509501
# 256    0.0  0.282609  0.235294  0.363636  0.344828  0.348485  0.439430
# ...    ...       ...       ...       ...       ...       ...       ...
# 23035  0.0  0.413043  0.382353  0.413876  0.310345  0.318182  0.427553
# 23036  0.0  0.217391  0.294118  0.224880  0.482759  0.560606  0.404988
# 23037  0.0  0.586957  0.455882  0.564593  0.517241  0.500000  0.480998
# 23038  0.0  0.347826  0.264706  0.430622  0.379310  0.500000  0.352732
# 23039  0.0  0.413043  0.426471  0.377990  0.448276  0.530303  0.395487
#
#              ft       fta       orb  ...  trb%_max_opp_10  ast%_max_opp_10  \
# ...

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# C:\Users\yb200\AppData\Local\Temp\ipykernel_17208\30860547.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# C:\Users\yb200\AppData\Local\Temp\ipykernel_17208\30860547.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# ...

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.500000  0.382353  0.523923  0.344828  0.333333  0.457245
# 249    0.0  0.630435  0.426471  0.645933  0.620690  0.515152  0.562945
# 254    0.0  0.456522  0.500000  0.375598  0.379310  0.348485  0.483373
# 255    0.0  0.326087  0.250000  0.413876  0.310345  0.257576  0.509501
# 256    0.0  0.282609  0.235294  0.363636  0.344828  0.348485  0.439430
# ...    ...       ...       ...       ...       ...       ...       ...
# 23035  0.0  0.413043  0.382353  0.413876  0.310345  0.318182  0.427553
# 23036  0.0  0.217391  0.294118  0.224880  0.482759  0.560606  0.404988
# 23037  0.0  0.586957  0.455882  0.564593  0.517241  0.500000  0.480998
# 23038  0.0  0.347826  0.264706  0.430622  0.379310  0.500000  0.352732
# 23039  0.0  0.413043  0.426471  0.377990  0.448276  0.530303  0.395487
#
#              ft       fta       orb  ...  blk%_max_opp_10  tov%_max_opp_10  \
# ...

# %%
full = df.merge(df[rolling_cols + ["team_opp_next", "date_next", "team"]], left_on=["team", "date_next"], right_on=["team_opp_next", "date_next"])

# %%
full
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.456522  0.500000  0.375598  0.379310  0.348485  0.483373
# 1      0.0  0.326087  0.250000  0.413876  0.310345  0.257576  0.509501
# 2      0.0  0.326087  0.558824  0.186603  0.206897  0.469697  0.203088
# 3      0.0  0.413043  0.397059  0.401914  0.137931  0.212121  0.263658
# 4      0.0  0.304348  0.323529  0.318182  0.275862  0.272727  0.432304
# ...    ...       ...       ...       ...       ...       ...       ...
# 20477  0.0  0.413043  0.352941  0.437799  0.344828  0.530303  0.304038
# 20478  0.0  0.413043  0.323529  0.464115  0.586207  0.636364  0.439430
# 20479  0.0  0.413043  0.382353  0.413876  0.310345  0.318182  0.427553
# 20480  0.0  0.217391  0.294118  0.224880  0.482759  0.560606  0.404988
# 20481  0.0  0.586957  0.455882  0.564593  0.517241  0.500000  0.480998
#
#              ft       fta       orb  ...  stl%_max_opp_10_y  \
# ...

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next
# 0        SAC             TOR    TOR             SAC  2015-11-15
# 1        TOR             SAC    SAC             TOR  2015-11-15
# 2        DEN             NOP    NOP             DEN  2015-11-17
# 3        ORL             MIN    MIN             ORL  2015-11-18
# 4        PHI             DAL    DAL             PHI  2015-11-16
# ...      ...             ...    ...             ...         ...
# 20477    BOS             DAL    DAL             BOS  2024-06-12
# 20478    BOS             DAL    DAL             BOS  2024-06-14
# 20479    DAL             BOS    BOS             DAL  2024-06-14
# 20480    BOS             DAL    DAL             BOS  2024-06-17
# 20481    DAL             BOS    BOS             DAL  2024-06-17
#
# [20482 rows x 5 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_10_x',
#  'team_opp_next_x',
#  'date_next',
#  'team_10_y',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=LogisticRegression(max_iter=3000),
#                           n_features_to_select=30, n_jobs=1)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['fga',
#  'tov',
#  'usg%',
#  'fga_max',
#  'drtg_max',
#  'fg_opp',
#  '3p_opp',
#  'usg%_opp',
#  '3par_max_opp',
#  'ts%_10_x',
#  'usg%_10_x',
#  'gmsc_max_10_x',
#  'trb%_opp_10_x',
#  'blk%_opp_10_x',
#  'usg%_opp_10_x',
#  'ortg_opp_10_x',
#  'drtg_opp_10_x',
#  'home_next',
#  'mp_10_y',
#  'tov_10_y',
#  'usg%_10_y',
#  'drtg_10_y',
#  'gmsc_max_10_y',
#  'stl%_max_10_y',
#  'blk%_opp_10_y',
#  'tov%_opp_10_y',
#  'usg%_opp_10_y',
#  'drtg_opp_10_y',
#  'tov_max_opp_10_y',
#  'ftr_max_opp_10_y']

# %%
predictions = backtest(full, lr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.6382157545080671
